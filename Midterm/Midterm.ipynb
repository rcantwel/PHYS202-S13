# %% [markdown]
# ####Problem 2

# %%
import numpy as np
t = arange(-pi , pi+0.01 , 0.1)
y = (cos(2*t)*cos(t/2))**2
xlabel( r'$ \theta (rad)$', fontsize = 20)
ylabel('$intensity$', fontsize = 20)
plot(t,y,'b*', color = "red",linewidth = 2.5, linestyle= "-", label = "$sin(4{\pi}t)$")
grid(True)

# %%
f = (1+t)/(t-1)
plot(f, label = "(1+t)/(t-1)" )
xlabel( 'time (seconds)', fontsize = 20)
ylabel('f(t), g(t)', fontsize = 20)
legend(loc = "lower left")

# %% [markdown]
# ####Problem 3

# %%
from Electrostatics import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-71-4e87070fcc71> in <module>()
# ----> 1 from Electrostatics import *
#
# ImportError: No module named Electrostatics

# %% [markdown]
# ###Problem 4

# %%
prefixes = 'JKLMNOPQ'
suffix = 'ack'
for letter in prefixes:
    if letter == "Q" or letter =="O": 
        print letter + "uack"
    else:
        print letter + suffix
# Out:
# Jack
# Kack
# Lack
# Mack
# Nack
# Ouack
# Pack
# Quack

# %%
def is_anagram(s1,s2): 
    for letters in s1:
        if len(s1) == len(s2):
            print "True"
