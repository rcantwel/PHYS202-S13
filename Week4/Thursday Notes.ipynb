# %%
from Electrostatics import *

# %%
x,y = meshgrid(arange(-3.,3.,0.037), arange(-3.,3.,0.037)) 
q = -3.e-9
d = 1
Vdp = dipolePotential(x,y,q,d)
print Vdp
# Out:
# [[-1.12324218 -1.12646686 -1.12937381 ...,  0.97852561  0.97131523
#    0.96406821]
#  [-1.14821577 -1.15181462 -1.15509272 ...,  0.99455602  0.98703299
#    0.97947821]
#  [-1.17380977 -1.17780363 -1.18147404 ...,  1.01082585  1.00298016
#    0.99510797]
#  ...,
#  [-1.17801956 -1.18207949 -1.1858156  ...,  1.01348678  1.00558782
#    0.99766324]
#  [-1.15232364 -1.1559851  -1.15932535 ...,  0.9971781   0.98960343
#    0.98199783]
#  [-1.12725038 -1.13053437 -1.1335001  ...,  0.98110889  0.97384848
#    0.96655221]]

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = figure() 
ax = fig.gca(projection = '3d') 
p = ax.plot_surface( x, y, Vdp, rstride = 1, cstride = 1, linewidth = 0, cmap=cm.coolwarm)
r = ax.plot_surface( x, y, pointPotential, rstride = 1, cstride = 1, linewidth = 0, cmap=cm.coolwarm)

cb = fig.colorbar(p, shrink = 0.5)



cset = ax.contour(x, y, Vdp, zdir = 'z', ofset = -40., cmap = cm.coolwarm)
cset = ax.contour(x, y, Vdp, zdir = 'x', ofset = -2., cmap = cm.coolwarm)
cset = ax.contour(x, y, Vdp, zdir = 'y', ofset = -2., cmap = cm.coolwarm)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-d277b952f213> in <module>()
#       4 ax = fig.gca(projection = '3d')
#       5 p = ax.plot_surface( x, y, Vdp, rstride = 1, cstride = 1, linewidth = 0, cmap=cm.coolwarm)
# ----> 6 r = ax.plot_surface( x, y, pointPotential, rstride = 1, cstride = 1, linewidth = 0, cmap=cm.coolwarm)
#       7
#       8 cb = fig.colorbar(p, shrink = 0.5)
#
# /usr/local/lib/python2.7/dist-packages/mpl_toolkits/mplot3d/axes3d.pyc in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1605                 lastp = np.array([])
#    1606                 ps2 = [ps[0]] + [ps[i] for i in xrange(1, len(ps)) if ps[i] != ps[i-1]]
# -> 1607                 avgzsum = sum(p[2] for p in ps2)
#    1608                 polys.append(ps2)
#    1609
#
# TypeError: unsupported operand type(s) for +: 'int' and 'function'

# %% [markdown]
# ##Using boolean masks to find data

# %%
theta = arange( 0., 2*pi, pi/100)
plot (theta, sin(theta))
show()

# %%
mask = (sin(theta) > 0) & (sin(theta) < 0.5) 
#print mask
plot (theta,sin(theta), theta[mask], sin(theta[mask]))

# %%
y = sin(theta[mask]) 
jj = (y== max(y))
y[jj] = NaN

# %%
plot(theta, sin(theta))
plot(theta[mask], y, linewidth=4)
show()

# %% [markdown]
# ##Interpolation

# %%
theta = arange (0., 2*pi+0.1, pi/10)
mask = (theta == 0.5)
print mask
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False]

# %%
newTheta = 0.5; newSin = 0.
from scipy.interpolate import interp1d
#help(interp1d)
sinInterp = interp1d(theta, sin(theta))

newSin = sinInterp(newTheta)
print newSin
# Out:
# 0.473922198704

# %%
plot(theta, sin(theta), newTheta, newSin, 'r*', markersize = 20, markeredgewidth= 3)
# Out:
# [<matplotlib.lines.Line2D at 0x79eea90>,
#  <matplotlib.lines.Line2D at 0x79eecd0>]

# %%
thetaNew = arange(0,2*pi+0.1, pi/30)
sinNew = interp1d(theta, sin(theta))(thetaNew)
plot(theta, sin(theta), thetaNew, sinNew, 'r.')
show()

# %%
plot(thetaNew, sinNew - sin(thetaNew))
ylabel('difference between interp and exact value')
show()

# %%
##LINEAR INTERPOLATION: Just assumes a straight line. Closer points is indicative of fewer errors.

# %%
sinNewC = interp1d(theta, sin(theta), kind = 'cubic')(thetaNew)
subplot(2,1,1)
plot (thetaNew,sinNew-sin(thetaNew), thetaNew, sinNewC - sin(thetaNew), 'r')
subplot(2,1,2) 
plot(thetaNew, sinNewC - sin(thetaNew), 'r' )
show()

# %%
help(interp1d)
# Out:
# Help on class interp1d in module scipy.interpolate.interpolate:
#
# class interp1d(__builtin__.object)
#  |  Interpolate a 1D function.
#  |
#  |  See Also
#  |  --------
#  |  splrep, splev - spline interpolation based on FITPACK
#  |  UnivariateSpline - a more recent wrapper of the FITPACK routines
#  |
#  |  Methods defined here:
#  |
#  |  __call__(self, x_new)
#  |      Find interpolated y_new = f(x_new).
#  |
#  |      Parameters
#  |      ----------
#  |      x_new : number or array
#  |          New independent variable(s).
#  |
#  |      Returns
#  |      -------
#  |      y_new : ndarray
#  |          Interpolated value(s) corresponding to x_new.
#  |
#  |  __init__(self, x, y, kind='linear', axis=-1, copy=True, bounds_error=True, fill_value=nan)
#  |      Initialize a 1D linear interpolation class.
#  |
#  |      Description
#  |      -----------
#  |      x and y are arrays of values used to approximate some function f:
#  |          y = f(x)
#  |      This class returns a function whose call method uses linear
#  |      interpolation to find the value of new points.
#  |
#  |      Parameters
#  |      ----------
#  |      x : array
#  |          A 1D array of monotonically increasing real values.  x cannot
#  |          include duplicate values (otherwise f is overspecified)
#  |      y : array
#  |          An N-D array of real values.  y's length along the interpolation
#  |          axis must be equal to the length of x.
#  |      kind : str or int
#  |          Specifies the kind of interpolation as a string ('linear',
#  |          'nearest', 'zero', 'slinear', 'quadratic, 'cubic') or as an integer
#  |          specifying the order of the spline interpolator to use.
#  |      axis : int
#  |          Specifies the axis of y along which to interpolate. Interpolation
#  |          defaults to the last axis of y.
#  |      copy : bool
#  |          If True, the class makes internal copies of x and y.
#  |          If False, references to x and y are used.
#  |          The default is to copy.
#  |      bounds_error : bool
#  |          If True, an error is thrown any time interpolation is attempted on
#  |          a value outside of the range of x (where extrapolation is
#  |          necessary).
#  |          If False, out of bounds values are assigned fill_value.
#  |          By default, an error is raised.
#  |      fill_value : float
#  |          If provided, then this value will be used to fill in for requested
#  |          points outside of the data range.
#  |          If not provided, then the default is NaN.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
